# %%
# prompt: unzip file DeepLearning-in-Atari-Games-main (1)

# !unzip DeepLearning-in-Atari-Games-main\ \(1\).zip
# Out:
# Archive:  DeepLearning-in-Atari-Games-main (1).zip
# 581c43ed4649fc17be64620d71d9c0b2c961684b
#    creating: DeepLearning-in-Atari-Games-main/
#   inflating: DeepLearning-in-Atari-Games-main/.DS_Store
#    creating: DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/
#   inflating: DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/.DS_Store
#    creating: DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/a2c/
#   inflating: DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/a2c/.DS_Store
#    creating: DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/a2c/__pycache__/
#   inflating: DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/a2c/__pycache__/actor_critic.cpython-37.pyc
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -r /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/requirements.txt --use-deprecated=legacy-resolver
# !pip install numpy
# !pip install opencv-contrib-python
# !apt-get install swig
# !pip install Box2D-py
# Out:
# ...
#   Using cached torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
# ...
#   Using cached torchvision-0.14.1-cp310-cp310-manylinux1_x86_64.whl (24.2 MB)
# ...
#   Using cached opencv_contrib_python-4.5.4.58-cp310-cp310-manylinux2014_x86_64.whl (66.5 MB)
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python' candidate (version 4.5.4.58 at https://files.pythonhosted.org/packages/ea/8c/e01428f31e473f765355c65c24f2dbd62a6a093a3248a9fa97bc65eeeb22/opencv_python-4.5.4.58-cp310-cp310-manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use  4.5.4.60
# ...
#   Using cached opencv_python-4.5.4.58-cp310-cp310-manylinux2014_x86_64.whl (60.3 MB)
# ...

# %%
# !bash -r /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/download.sh
# Out:
# --2024-11-22 11:02:55--  https://docs.google.com/uc?export=download&confirm=&id=19HYf-zNFscvE-Eqyzmcl0GkkCfVvj3XF
# Resolving docs.google.com (docs.google.com)... 142.250.153.138, 142.250.153.100, 142.250.153.139, ...
# Connecting to docs.google.com (docs.google.com)|142.250.153.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=19HYf-zNFscvE-Eqyzmcl0GkkCfVvj3XF&export=download [following]
# --2024-11-22 11:02:55--  https://drive.usercontent.google.com/download?id=19HYf-zNFscvE-Eqyzmcl0GkkCfVvj3XF&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18716612 (18M) [application/octet-stream]
# Saving to: ‘download.zip’
#
# ...

# %%
# !unzip /content/download.zip
# Out:
# Archive:  /content/download.zip
#    creating: model/
#    creating: model/best/
#   inflating: model/best/a2c.cpt
#   inflating: model/best/dqn.cpt
#   inflating: model/best/pg.cpt

# %%
# !pip install gym[atari] autorom[accept-rom-license]

# %%
# !python /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/main.py --train_dqn --dqn_type=DQN  --folder_name=content --video_dir=train_video_dqn_save
# Out:
# Using DQN Network
# Exploring phase | Episode: 100 | Steps: 14244/3000000 | epsilon: 0.930561 | Avg reward: 3.120000 | Loss: 0.019299
# Exploring phase | Episode: 200 | Steps: 28439/3000000 | epsilon: 0.861360 | Avg reward: 3.160000 | Loss: 0.024880
# Exploring phase | Episode: 300 | Steps: 43063/3000000 | epsilon: 0.790068 | Avg reward: 3.070000 | Loss: 0.029565
# Exploring phase | Episode: 400 | Steps: 56682/3000000 | epsilon: 0.723675 | Avg reward: 2.810000 | Loss: 0.031794
# Exploring phase | Episode: 500 | Steps: 69926/3000000 | epsilon: 0.659111 | Avg reward: 2.670000 | Loss: 0.032998
# Exploring phase | Episode: 600 | Steps: 84927/3000000 | epsilon: 0.585981 | Avg reward: 3.250000 | Loss: 0.034450
# Exploring phase | Episode: 700 | Steps: 100048/3000000 | epsilon: 0.512266 | Avg reward: 3.010000 | Loss: 0.035356
# Exploring phase | Episode: 800 | Steps: 114684/3000000 | epsilon: 0.440916 | Avg reward: 3.230000 | Loss: 0.039834
# ...

# %%
# !python /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/main.py --test_dqn --dqn_type=DQN --model_path=/content/model/content/e1700_r9.69_model.cpt --video_dir=dqntestvideo
# Out:
# Using DQN Network
# Load model from /content/model/content/e1700_r9.69_model.cpt
# Episode:100/100 | reward: 30.00
# Run 100 episodes
# Mean: 189.33

# %%
# !pip install  matplotlib

# %%
# !pip install numpy

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import json
from sys import argv


with open("/content/model/content/plot.json", 'r') as f:
   reward = json.load(f)

reward = reward['reward']

avg = 10
window = int(len(reward)/avg)
fig, ((ax1), (ax2)) = plt.subplots(2, 1, figsize=[9,9]);
rolling_mean = pd.Series(reward).rolling(window).mean()
std = pd.Series(reward).rolling(window).std()
ax1.plot(rolling_mean)
ax1.fill_between(range(len(reward)),rolling_mean-std, rolling_mean+std, color='orange', alpha=0.2)
ax1.set_title('Average Reward (last {}-episode window)'.format(avg))
ax1.set_xlabel('Episode');
ax1.set_ylabel('Average Reward')
ax2.plot(reward)
ax2.set_title('Average Reward (all)')
ax2.set_xlabel('Episode');
ax2.set_ylabel('Average Reward')
fig.tight_layout(pad=2)
plt.show()

# %%
# !python /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/main.py --train_dqn --dqn_type=DoubleDQN  --folder_name=DDeepQL --video_dir=train_video_ddqn
# Out:
# Using DoubleDQN Network
# Exploring phase | Episode: 100 | Steps: 15056/3000000 | epsilon: 0.926602 | Avg reward: 2.990000 | Loss: 0.021803
# Exploring phase | Episode: 200 | Steps: 29715/3000000 | epsilon: 0.855139 | Avg reward: 3.000000 | Loss: 0.020757
# Exploring phase | Episode: 300 | Steps: 44099/3000000 | epsilon: 0.785017 | Avg reward: 3.200000 | Loss: 0.022258
# Exploring phase | Episode: 400 | Steps: 58676/3000000 | epsilon: 0.713955 | Avg reward: 3.000000 | Loss: 0.026781
# Exploring phase | Episode: 500 | Steps: 72971/3000000 | epsilon: 0.644266 | Avg reward: 3.210000 | Loss: 0.024829
# Exploring phase | Episode: 600 | Steps: 87204/3000000 | epsilon: 0.574881 | Avg reward: 3.110000 | Loss: 0.024765
# Exploring phase | Episode: 700 | Steps: 101205/3000000 | epsilon: 0.506626 | Avg reward: 3.130000 | Loss: 0.022961
# Exploring phase | Episode: 800 | Steps: 116395/3000000 | epsilon: 0.432574 | Avg reward: 3.490000 | Loss: 0.025425
# ...

# %%
# !python /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/main.py --test_dqn --dqn_type=DoubleDQN --model_path=/content/model/DDeepQL/e1700_r10.05_model.cpt --video_dir=ddqntestvideo
# Out:
# Using DoubleDQN Network
# Load model from /content/model/DDeepQL/e1700_r10.05_model.cpt
# Episode:100/100 | reward: 31.00
# Run 100 episodes
# Mean: 198.66

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import json
from sys import argv


with open("/content/model/DDeepQL/plot.json", 'r') as f:
   reward = json.load(f)

reward = reward['reward']

avg = 10
window = int(len(reward)/avg)
fig, ((ax1), (ax2)) = plt.subplots(2, 1, figsize=[9,9]);
rolling_mean = pd.Series(reward).rolling(window).mean()
std = pd.Series(reward).rolling(window).std()
ax1.plot(rolling_mean)
ax1.fill_between(range(len(reward)),rolling_mean-std, rolling_mean+std, color='orange', alpha=0.2)
ax1.set_title('Average Reward (last {}-episode window)'.format(avg))
ax1.set_xlabel('Episode');
ax1.set_ylabel('Average Reward')
ax2.plot(reward)
ax2.set_title('Average Reward (all)')
ax2.set_xlabel('Episode');
ax2.set_ylabel('Average Reward')
fig.tight_layout(pad=2)
plt.show()

# %%
# !python /content/DeepLearning-in-Atari-Games-main/Deep-Reinforcement-Learning-on-Atari-Games-master/plot.py /content/model/DDeepQL/plot.json
# Out:
# Figure(900x900)

# %%
# !pip install -U matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 87.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
# ...

# %%
# !zip -r video.zip train_video_dqn_save/
# Out:
# updating: train_video_dqn_save/ (stored 0%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video001000.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000512.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000064.meta.json (deflated 60%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000027.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000000.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000343.mp4 (deflated 11%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video003000.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000343.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video002000.meta.json (deflated 61%)
# updating: train_video_dqn_save/openaigym.video.0.11113.video000216.mp4 (deflated 8%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
